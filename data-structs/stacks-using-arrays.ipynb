# %%
L = [1,2,3,4,5]

# %%
L.append(11)

# %%
L.pop()
# Out:
# 11

# %%
print(L)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(L)
# Out:
# 5

# %%
# peek simulation
L[-1]
# Out:
# 5

# %%
# Custom implementation

class Stack:
    def __init__(self, size):
        self.size = size
        self.stack = [None] * self.size
        self.length = -1
        self.top = None

    def push(self, item):
        if self.length == self.size - 1:
            return "OverflowError"
        else:
            self.length += 1
            self.stack[self.length] = item
            self.top = self.stack[self.length]

    def pop(self):
        if self.length == -1:
            return "Empty"
        else:
            elem = self.top
            self.stack[self.length] = None
            self.length -= 1
            self.top = self.stack[self.length]

            return elem

s = Stack(5)
s.push(4)
s.push(77)
print(s.stack)
print(s.top, s.pop(), s.stack)
print(s.top, s.pop(), s.stack)
print(s.top, s.pop(), s.stack)
# Out:
# [4, 77, None, None, None]
# 77 77 [4, None, None, None, None]
# 4 4 [None, None, None, None, None]
# None Empty [None, None, None, None, None]
