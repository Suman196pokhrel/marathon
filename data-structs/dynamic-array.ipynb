# %%
import sys

# %%
# Quick demo of how python's default list/array displays dynamic arrays nature
L = []
name = "sumanpokhre12121112"
sys.getsizeof(L)
for i,elem in enumerate(name):
    L.append(elem)
    print(f"{sys.getsizeof(L)}",end=",")
# Out:
# 88,88,88,88,120,120,120,120,184,184,184,184,184,184,184,184,248,248,248,
